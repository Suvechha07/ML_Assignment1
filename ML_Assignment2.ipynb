# %% [markdown]
# <a href="https://colab.research.google.com/github/Suvechha07/ML_Assignment1/blob/main/ML_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Cost function for logistic regression
def compute_cost(X, y, theta):
    m = len(y)
    h = sigmoid(X @ theta)
    cost = (-1 / m) * (y.T @ np.log(h) + (1 - y).T @ np.log(1 - h))
    return cost[0, 0]  # Return as a scalar

# Gradient descent function for logistic regression
def gradient_descent(X, y, theta, learning_rate, num_iterations):
    m = len(y)
    cost_history = []

    for _ in range(num_iterations):
        h = sigmoid(X @ theta)
        gradient = (1 / m) * (X.T @ (h - y))  # Compute gradient
        theta -= learning_rate * gradient  # Update parameters
        cost = compute_cost(X, y, theta)  # Compute the cost
        cost_history.append(cost)

    return theta, cost_history

# Load dataset from CSV files
def load_dataset():
    # Load features (X) and target labels (y) from CSV files
    X = pd.read_csv('/content/logisticX.csv', header=None).values
    y = pd.read_csv('/content/logisticY.csv', header=None).values

    # Add bias term (column of 1s)
    X = np.hstack((np.ones((X.shape[0], 1)), X))  # Add bias term as the first column

    return X, y

# Visualize the dataset
def plot_dataset(X, y):
    plt.scatter(X[y.flatten() == 0][:, 1], X[y.flatten() == 0][:, 2], color="red", label="Class 0")
    plt.scatter(X[y.flatten() == 1][:, 1], X[y.flatten() == 1][:, 2], color="blue", label="Class 1")
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.legend()
    plt.title("Dataset")
    plt.show()

# Main function
if __name__ == "__main__":
    # Load and visualize the dataset
    X, y = load_dataset()
    plot_dataset(X, y)

    # Initialize parameters
    theta = np.zeros((X.shape[1], 1))
    learning_rate = 0.01
    num_iterations = 1000

    # Perform gradient descent
    theta, cost_history = gradient_descent(X, y, theta, learning_rate, num_iterations)

    # Plot cost history
    plt.plot(range(len(cost_history)), cost_history, label="Cost")
    plt.xlabel("Iterations")
    plt.ylabel("Cost")
    plt.title("Cost Function Convergence")
    plt.legend()
    plt.show()

    # Final results
    print("Optimized theta:", theta)
    print("Final cost:", cost_history[-1])
# Out:
# Optimized theta: [[ 0.00390705]
#  [ 1.18020141]
#  [-1.17531578]]
# Final cost: 0.2548430124077635

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Cost function for logistic regression
def compute_cost(X, y, theta):
    m = len(y)
    h = sigmoid(X @ theta)
    cost = (-1 / m) * (y.T @ np.log(h) + (1 - y).T @ np.log(1 - h))
    return cost[0, 0]  # Return as a scalar

# Gradient descent function for logistic regression
def gradient_descent(X, y, theta, learning_rate, num_iterations):
    m = len(y)
    cost_history = []

    for _ in range(num_iterations):
        h = sigmoid(X @ theta)
        gradient = (1 / m) * (X.T @ (h - y))  # Compute gradient
        theta -= learning_rate * gradient  # Update parameters
        cost = compute_cost(X, y, theta)  # Compute the cost
        cost_history.append(cost)

    return theta, cost_history

# Load dataset from CSV files
def load_dataset():
    # Load features (X) and target labels (y) from CSV files
    X = pd.read_csv('/content/logisticX.csv', header=None).values
    y = pd.read_csv('/content/logisticY.csv', header=None).values

    # Add bias term (column of 1s)
    X = np.hstack((np.ones((X.shape[0], 1)), X))  # Add bias term as the first column

    return X, y

# Main function
if __name__ == "__main__":
    # Load the dataset
    X, y = load_dataset()

    # Initialize parameters
    theta = np.zeros((X.shape[1], 1))
    learning_rate = 0.01
    num_iterations = 1000

    # Perform gradient descent
    theta, cost_history = gradient_descent(X, y, theta, learning_rate, num_iterations)

    # Plot cost function vs iteration for the first 50 iterations
    plt.figure(figsize=(8, 6))
    plt.plot(range(50), cost_history[:50], label="Cost")
    plt.xlabel("Iterations")
    plt.ylabel("Cost")
    plt.title("Cost Function vs Iterations (First 50 Iterations)")
    plt.legend()
    plt.grid()
    plt.show()

    # Final results
    print("Optimized theta:", theta)
    print("Final cost:", cost_history[-1])
# Out:
# Optimized theta: [[ 0.00390705]
#  [ 1.18020141]
#  [-1.17531578]]
# Final cost: 0.2548430124077635

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Decision boundary function
def plot_decision_boundary(X, y, theta):
    # Scatter plot of the dataset
    plt.figure(figsize=(8, 6))
    for i in range(len(y)):
        if y[i] == 0:
            plt.scatter(X[i, 1], X[i, 2], c='red', label="Class 0" if i == 0 else "")
        else:
            plt.scatter(X[i, 1], X[i, 2], c='blue', label="Class 1" if i == 0 else "")

    # Plot the decision boundary
    x_values = [min(X[:, 1]) - 1, max(X[:, 1]) + 1]
    y_values = [-(theta[0] + theta[1] * x) / theta[2] for x in x_values]
    plt.plot(x_values, y_values, label="Decision Boundary", color="green")

    # Formatting the graph
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.title("Dataset with Decision Boundary")
    plt.legend()
    plt.grid()
    plt.show()

# Load dataset from CSV files
def load_dataset():
    # Load features (X) and target labels (y) from CSV files
    X = pd.read_csv('/content/logisticX.csv', header=None).values
    y = pd.read_csv('/content/logisticY.csv', header=None).values

    # Add bias term (column of 1s)
    X = np.hstack((np.ones((X.shape[0], 1)), X))  # Add bias term as the first column

    return X, y

# Compute the cost function
def compute_cost(X, y, theta):
    m = len(y)
    h = sigmoid(X @ theta)
    cost = -(1 / m) * (y.T @ np.log(h) + (1 - y).T @ np.log(1 - h))
    return cost

# Gradient descent function for logistic regression
def gradient_descent(X, y, theta, learning_rate, num_iterations):
    m = len(y)
    cost_history = []

    for _ in range(num_iterations):
        h = sigmoid(X @ theta)
        gradient = (1 / m) * (X.T @ (h - y))
        theta -= learning_rate * gradient
        cost = compute_cost(X, y, theta)
        cost_history.append(cost)

    return theta, cost_history

# Main function
if __name__ == "__main__":
    # Load the dataset
    X, y = load_dataset()

    # Initialize parameters
    theta = np.zeros((X.shape[1], 1))
    learning_rate = 0.01
    num_iterations = 1000

    # Train the logistic regression model
    theta, cost_history = gradient_descent(X, y, theta, learning_rate, num_iterations)

    # Print final parameters
    print("Trained Parameters (theta):")
    print(theta)

    # Plot the dataset and decision boundary
    plot_decision_boundary(X, y, theta)
# Out:
# Trained Parameters (theta):
# [[ 0.00390705]
#  [ 1.18020141]
#  [-1.17531578]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Decision boundary function
def plot_decision_boundary(X, y, theta):
    # Scatter plot of the dataset
    plt.figure(figsize=(8, 6))
    for i in range(len(y)):
        if y[i] == 0:
            plt.scatter(X[i, 1], X[i, 2], c='red', label="Class 0" if i == 0 else "")
        else:
            plt.scatter(X[i, 1], X[i, 2], c='blue', label="Class 1" if i == 0 else "")

    # Plot the decision boundary
    x_values = [min(X[:, 1]) - 1, max(X[:, 1]) + 1]
    y_values = [-(theta[0] + theta[1] * x) / theta[2] for x in x_values]
    plt.plot(x_values, y_values, label="Decision Boundary", color="green")

    # Formatting the graph
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.title("Dataset with Decision Boundary")
    plt.legend()
    plt.grid()
    plt.show()

# Load dataset from CSV files
def load_dataset():
    # Load features (X) and target labels (y) from CSV files
    X = pd.read_csv('/content/logisticX.csv', header=None).values
    y = pd.read_csv('/content/logisticY.csv', header=None).values

    # Add bias term (column of 1s)
    X = np.hstack((np.ones((X.shape[0], 1)), X))  # Add bias term as the first column

    return X, y

# Compute the cost function
def compute_cost(X, y, theta):
    m = len(y)
    h = sigmoid(X @ theta)
    cost = -(1 / m) * (y.T @ np.log(h) + (1 - y).T @ np.log(1 - h))
    return cost

# Gradient descent function for logistic regression
def gradient_descent(X, y, theta, learning_rate, num_iterations):
    m = len(y)
    cost_history = []

    for _ in range(num_iterations):
        h = sigmoid(X @ theta)
        gradient = (1 / m) * (X.T @ (h - y))
        theta -= learning_rate * gradient
        cost = compute_cost(X, y, theta)
        cost_history.append(cost)

    return theta, cost_history

# Main function
if __name__ == "__main__":
    # Load the dataset
    X, y = load_dataset()

    # Introduce two new independent variables (squares of the original features)
    X_new = np.hstack((X, X[:, 1:]**2))  # Add squared features to X

    # Initialize parameters
    theta = np.zeros((X_new.shape[1], 1))
    learning_rate = 0.01
    num_iterations = 1000

    # Train the logistic regression model
    theta, cost_history = gradient_descent(X_new, y, theta, learning_rate, num_iterations)

    # Print final parameters
    print("Trained Parameters (theta) for new features:")
    print(theta)

    # Plot the dataset and decision boundary with new features
    plot_decision_boundary(X_new, y, theta)
# Out:
# Trained Parameters (theta) for new features:
# [[-0.0047076 ]
#  [ 0.00993278]
#  [-0.03236892]
#  [ 0.22821589]
#  [-0.21187826]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, ConfusionMatrixDisplay

# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Logistic regression model functions (same as earlier)
def compute_cost(X, y, theta):
    m = len(y)
    h = sigmoid(X @ theta)
    cost = -(1 / m) * (y.T @ np.log(h) + (1 - y).T @ np.log(1 - h))
    return cost

def gradient_descent(X, y, theta, learning_rate, num_iterations):
    m = len(y)
    cost_history = []

    for _ in range(num_iterations):
        h = sigmoid(X @ theta)
        gradient = (1 / m) * (X.T @ (h - y))
        theta -= learning_rate * gradient
        cost = compute_cost(X, y, theta)
        cost_history.append(cost)

    return theta, cost_history

# Load dataset (same as earlier)
def load_dataset():
    X = pd.read_csv('/content/logisticX.csv', header=None).values
    y = pd.read_csv('/content/logisticY.csv', header=None).values
    X = np.hstack((np.ones((X.shape[0], 1)), X))  # Add bias term as the first column
    return X, y

# Predict function
def predict(X, theta):
    return sigmoid(X @ theta) >= 0.5

# Main function
if __name__ == "__main__":
    # Load the dataset
    X, y = load_dataset()

    # Introduce two new independent variables (squares of the original features)
    X_new = np.hstack((X, X[:, 1:]**2))  # Add squared features to X

    # Initialize parameters
    theta = np.zeros((X_new.shape[1], 1))
    learning_rate = 0.01
    num_iterations = 1000

    # Train the logistic regression model
    theta, cost_history = gradient_descent(X_new, y, theta, learning_rate, num_iterations)

    # Make predictions on the dataset
    y_pred = predict(X_new, theta)

    # Compute confusion matrix
    cm = confusion_matrix(y, y_pred)
    print("Confusion Matrix:")
    print(cm)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y, y_pred)
    precision = precision_score(y, y_pred)
    recall = recall_score(y, y_pred)
    f1 = f1_score(y, y_pred)

    # Print the evaluation metrics
    print(f"\nAccuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")

    # Plot confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.show()
# Out:
# Confusion Matrix:
# [[45  5]
#  [ 8 42]]
#
# Accuracy: 0.8700
# Precision: 0.8936
# Recall: 0.8400
# F1-Score: 0.8660
